# %% [markdown]
# <h2>Create a Python file named Module:
# <br>a. Inside the file, define 4 methods named – addition, subtraction,
# multiplication, and division.
# <br>b. Each method should only accept 2 arguments and should return the
# result of operation performed in each method. For e.g., addition() should
# return the sum of two arguments.
# <br>c. Save the Module file in .py format</h2>

# %% [markdown]
# # Module.py
# def addition(a, b):
#     return a + b
#
# def subtraction(a, b):
#     return a - b
#
# def multiplication(a, b):
#     return a * b
#
# def division(a, b):
#     if b != 0:
#         return a / b
#     else:
#         return "Division by zero is not allowed"

# %% [markdown]
# <h2>Open a new python file and import the Module.py file a. Now call the 4 methods from the Module.py file, i.e., addition(), subtraction(), multiplication() and Divison()</h2>

# %%
# import.py
from Module import addition, subtraction, multiplication, division

a = int(input("Enter the first number: "))
b = int(input("Enter the second number: "))

print("Addition: ", addition(a, b))
print("Subtraction: ", subtraction(a, b))
print("Multiplication: ", multiplication(a, b))
print("Division: ", division(a, b))
# Out:
# Enter the first number:  5
# Enter the second number:  4
# Addition:  9
# Subtraction:  1
# Multiplication:  20
# Division:  1.25

# %% [markdown]
# <h2>From the Module file, import only the addition() and pass the arguments so that it can display the result from the method</h2>

# %%
# import.py
from Module import addition
a = int(input("Enter the first number: "))
b = int(input("Enter the second number: "))

print("Addition: ", addition(a, b))
# Out:
# Enter the first number:  5
# Enter the second number:  5
# Addition:  10

# %% [markdown]
# <h2> From the Module file, import only the subtraction() and pass the arguments
# so that it can display the result from the method.</h2>

# %%
# import.py
from Module import subtraction

a = int(input("Enter the first number: "))
b = int(input("Enter the second number: "))


print("Subtraction: ", subtraction(a, b))
# Out:
# Enter the first number:  5
# Enter the second number:  4
# Subtraction:  1

# %% [markdown]
# <h2>From the Module file, import both the multiplication() and division() and
# pass the arguments so that it can display the result from the methods.
# </h2>

# %%
# import.py
from Module import multiplication, division

a = int(input("Enter the first number: "))
b = int(input("Enter the second number: "))

print("Multiplication: ", multiplication(a, b))
print("Division: ", division(a, b))
# Out:
# Enter the first number:  4
# Enter the second number:  5
# Multiplication:  20
# Division:  0.8
