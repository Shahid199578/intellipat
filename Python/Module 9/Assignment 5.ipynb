# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# Load dataset (Update the file path if needed)
df = pd.read_csv('Retail.csv', header=None, encoding='latin1')

# Clean dataset: Extract only transactions and remove NaN values
df_cleaned = df.iloc[2:, 0].dropna()  # Extract only transactions and remove NaN values

# Convert transactions into a list of lists
transactions = df_cleaned.apply(lambda x: x.split(":")[-1].replace("{", "").replace("}", "").split(","))

# Trim whitespace from items
transactions = transactions.apply(lambda items: [item.strip() for item in items])

# Convert to list format
transactions_list = transactions.tolist()

# Encode transactions into a binary format
te = TransactionEncoder()
te_ary = te.fit(transactions_list).transform(transactions_list)
df_transformed = pd.DataFrame(te_ary, columns=te.columns_)

# Generate frequent itemsets using the Apriori algorithm (adjust min_support if needed)
frequent_itemsets = apriori(df_transformed, min_support=0.005, use_colnames=True)

# Display frequent itemsets
print("Frequent Itemsets:")
print(frequent_itemsets)


rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1.0)

# Display the association rules
print("\nAssociation Rules:")
print(rules)
# Out:
# Frequent Itemsets:
#      support                                           itemsets
# 0        0.1                                      (Cad Holders)
# 1        0.1                                     (Card Holders)
# 2        0.2                                          (Envelop)
# 3        0.7                                          (Erasers)
# 4        0.1                                      (Highlighter)
# ..       ...                                                ...
# 161      0.1  (Pencils, Highlighter, StaplerPins, Post-it, E...
# 162      0.1  (Pencils, Highlighter, StaplerPins, Post-it, E...
# 163      0.1  (Pencils, StaplerPins, Post-it, Erasers, Paper...
# 164      0.1  (Pencils, Highlighter, StaplerPins, Post-it, P...
# 165      0.1  (Pencils, Highlighter, StaplerPins, Post-it, E...
#
# [166 rows x 2 columns]
#
# Association Rules:
#          antecedents                                        consequents  \
# ...
