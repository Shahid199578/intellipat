# %% [raw]
# 1. Create 1st tuple with values -> (10, 20, 30), 2nd tuple with values -> (40, 50, 60):
# a. Concatenate the two tuples and store it in “t_combine”
# b. Repeat the elements of “t_combine” 3 times
# c. Access the 3rd element from “t_combine”
# d. Access the first three elements from “t_combine”
# e. Access the last three elements from “t_combine”

# %%
# Create 1st tuple with values -> (10, 20, 30), 2nd tuple with values -> (40, 50, 60)
tuple1 = (10, 20, 30)
tuple2 = (40, 50, 60)

# a. Concatenate the two tuples and store it in “t_combine”
t_combine = tuple1 + tuple2
print("Concatenated tuple:", t_combine)

# b. Repeat the elements of “t_combine” 3 times
t_repeated = t_combine * 3
print("Repeated tuple:", t_repeated)

# c. Access the 3rd element from “t_combine”
third_element = t_combine[2]
print("3rd element from t_combine:", third_element)

# d. Access the first three elements from “t_combine”
first_three_elements = t_combine[:3]
print("First three elements from t_combine:", first_three_elements)

# e. Access the last three elements from “t_combine”
last_three_elements = t_combine[-3:]
print("Last three elements from t_combine:", last_three_elements)
# Out:
# Concatenated tuple: (10, 20, 30, 40, 50, 60)
# Repeated tuple: (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)
# 3rd element from t_combine: 30
# First three elements from t_combine: (10, 20, 30)
# Last three elements from t_combine: (40, 50, 60)

# %% [markdown]
# 2. Create a list ‘my_list’ with these elements:
# a. First element is a tuple with values 1, 2, 3
# b. Second element is a tuple with values “a”, “b”, “c”
# c. Third element is a tuple with values True, False

# %%
# Create a list ‘my_list’ with specified elements
my_list = [
    (1, 2, 3),          # First element is a tuple with values 1, 2, 3
    ("a", "b", "c"),    # Second element is a tuple with values “a”, “b”, “c”
    (True, False)       # Third element is a tuple with values True, False
]
print("Initial my_list:", my_list)
# Out:
# Initial my_list: [(1, 2, 3), ('a', 'b', 'c'), (True, False)]

# %% [raw]
# 3. Append a new tuple – (1, ‘a’, True) to ‘my_list’:
# a. Append a new list – *“sparta”, 123+ to my_list

# %%
# Append a new tuple – (1, ‘a’, True) to ‘my_list’
my_list.append((1, 'a', True))
print("my_list after appending a new tuple:", my_list)

# a. Append a new list – *“sparta”, 123+ to my_list
my_list.append(["sparta", 123])
print("my_list after appending a new list:", my_list)
# Out:
# my_list after appending a new tuple: [(1, 2, 3), ('a', 'b', 'c'), (True, False), (1, 'a', True)]
# my_list after appending a new list: [(1, 2, 3), ('a', 'b', 'c'), (True, False), (1, 'a', True), ['sparta', 123]]

# %% [raw]
# 4. Create a dictionary ‘fruit’ where:
# a. The first key is ‘Fruit’ and the values are (“Apple”, “Banana”, “Mango”,
# “Guava”)
# b. The second key is ‘Cost’ and the values are (85, 54, 120, 70)
# c. Extract all the keys from ‘fruit’
# d. Extract all the values from ‘fruit’

# %%
# Create a dictionary ‘fruit’ with specified keys and values
fruit = {
    'Fruit': ("Apple", "Banana", "Mango", "Guava"),
    'Cost': (85, 54, 120, 70)
}

# a. Extract all the keys from ‘fruit’
fruit_keys = fruit.keys()
print("Keys of fruit dictionary:", fruit_keys)

# b. Extract all the values from ‘fruit’
fruit_values = fruit.values()
print("Values of fruit dictionary:", fruit_values)
# Out:
# Keys of fruit dictionary: dict_keys(['Fruit', 'Cost'])
# Values of fruit dictionary: dict_values([('Apple', 'Banana', 'Mango', 'Guava'), (85, 54, 120, 70)])

# %% [raw]
# 5. Create a set named ‘my_set’ with values (1, 1, “a”, “a”, True, True) and
# print the result.

# %%
# Create a set named ‘my_set’ with specified values and print the result
my_set = {1, 1, "a", "a", True, True}
print("my_set:", my_set)
# Out:
# my_set: {1, 'a'}
