# %%
a = int(input("Enter the first number: "))
b = int(input("Enter the second number: "))
c = int(input("Enter the third number: "))

# Check which one is the greatest
if a > b and a > c:
    print("The greatest number is:", a)
elif b > a and b > c:
    print("The greatest number is:", b)
elif c > a and c > b:
    print("The greatest number is:", c)
else:
    # Handle edge cases where two or more numbers are equal
    if a == b and b == c:
        print("All three numbers are equal.")
    elif a == b:
        if a > c:
            print("The greatest numbers are:", a, "and", b)
        else:
            print("The greatest number is:", c)
    elif a == c:
        if a > b:
            print("The greatest numbers are:", a, "and", c)
        else:
            print("The greatest number is:", b)
    elif b == c:
        if b > a:
            print("The greatest numbers are:", b, "and", c)
        else:
            print("The greatest number is:", a)
# Out:
# Enter the first number:  2
# Enter the second number:  3
# Enter the third number:  2
# The greatest number is: 3
