# %%
import pandas as pd

# Load the dataset
churn = pd.read_csv('customer_churn.csv')

# 1. Sort the DataFrame by the 'tenure' column in descending order
sorted_churn = churn.sort_values(by='tenure', ascending=False)
print("Sorted Data (Descending Order by Tenure):\n", sorted_churn.head(10))  # Display top 10 for verification

# 2a. Fetch records where Tenure > 50 and Gender is 'Female'
tenure_female = churn[(churn['tenure'] > 50) & (churn['gender'] == 'Female')]
print("\nRecords where Tenure > 50 and Gender is 'Female':\n", tenure_female)

# 2b. Fetch records where Gender is 'Male' and SeniorCitizen is 0
male_non_senior = churn[(churn['gender'] == 'Male') & (churn['SeniorCitizen'] == 0)]
print("\nRecords where Gender is 'Male' and SeniorCitizen is 0:\n", male_non_senior)

# 2c. Fetch records where TechSupport is 'Yes' and Churn is 'No'
techsupport_no_churn = churn[(churn['TechSupport'] == 'Yes') & (churn['Churn'] == 'No')]
print("\nRecords where TechSupport is 'Yes' and Churn is 'No':\n", techsupport_no_churn)

# 2d. Fetch records where Contract is 'Month-to-month' and Churn is 'Yes'
month_to_month_churn = churn[(churn['Contract'] == 'Month-to-month') & (churn['Churn'] == 'Yes')]
print("\nRecords where Contract is 'Month-to-month' and Churn is 'Yes':\n", month_to_month_churn)
# Out:
# Sorted Data (Descending Order by Tenure):
#        customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 3177  1814-WFGVS    Male              0     Yes        Yes      72
# 3131  8336-TAVKX  Female              1     Yes         No      72
# 3107  5038-ETMLM  Female              0     Yes         No      72
# 35    6234-RAAPL  Female              0     Yes        Yes      72
# 3111  8809-RIHDD    Male              0     Yes        Yes      72
# 3112  8809-XKHMD    Male              0     Yes         No      72
# 3203  5879-HMFFH  Female              0     Yes         No      72
# 3205  3810-DVDQQ  Female              0     Yes        Yes      72
# 3247  8853-TZDGH  Female              0      No         No      72
# 3266  0464-WJTKO  Female              0     Yes        Yes      72
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 3177           No  No phone service             DSL                  Yes  ...
# ...
